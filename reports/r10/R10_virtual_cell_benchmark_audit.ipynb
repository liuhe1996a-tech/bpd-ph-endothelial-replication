# %% [markdown]
# # R10 two-cohort perturbation-prediction benchmark audit
#
# This output-populated audit notebook was generated by the released reporting script from the frozen result tables. It does not refit a model.

# %%
# Validate fold-only features and animal-grouped ledgers
# Out:
# GSE151974
#              model_features  primary_hvgs
# heldout_age
# P14                    1800          1800
# P3                     1800          1800
# P7                     1800          1800
#
# GSE243129
#              model_features  primary_hvgs
# heldout_age
# P14                    1800          1800
# P7                     1800          1800

# %%
# Summarize primary endpoint point estimates and ranks
# Out:
# cohort               GSE151974  GSE243129  rank_GSE151974  rank_GSE243129
# method
# gene_linear             0.2506     0.0432               7               7
# pca_latent              0.5137     0.3643               2               6
# vae_latent              0.4910     0.4052               3               3
# cvae_counterfactual     0.4405     0.4094               6               2
# scgen_adapted           0.4643     0.4117               5               1
# cpa_adapted             0.4697     0.4026               4               4
# sinkhorn_ot             0.5336     0.3836               1               5

# %%
# Audit exact GSE243129 animal-subset sensitivity
# Out:
# {
#   "analysis_version": "R10 exact GSE243129 animal sensitivity",
#   "animals_total": 8,
#   "animals_per_age_by_oxygen": 2,
#   "joint_application_to_cap_and_cap_a": true,
#   "model_refitting_per_configuration": false,
#   "all_nonempty_subset_configurations": 81,
#   "one_pair_configurations": 16,
#   "leave_one_animal_configurations": 8,
#   "bootstrap_replicates": 500,
#   "unique_unordered_configurations": 77,
#   "maximum_possible_unordered_configurations": 81,
#   "interpretation": "The bootstrap quantifies resampling variability from eight animals; it does not create additional biological replication."
# }
#
#             analysis              method  configurations  mean_spearman  minimum_spearman  maximum_spearman  median_rank  minimum_rank  maximum_rank  times_ranked_first  times_ranked_top3  fraction_ranked_first  fraction_ranked_top3
# all_nonempty_subsets         cpa_adapted              81       0.438755          0.327489          0.538949          4.0           1.0           5.0                   5                 27               0.061728              0.333333
# all_nonempty_subsets cvae_counterfactual              81       0.448385          0.326773          0.562387          2.0           1.0           5.0                   1                 75               0.012346              0.925926
# all_nonempty_subsets         gene_linear              81       0.056971          0.018890          0.107016          7.0           7.0           7.0                   0                  0               0.000000              0.000000
# all_nonempty_subsets          pca_latent              81       0.403739          0.284939          0.526341          6.0           6.0           6.0                   0                  0               0.000000              0.000000
# all_nonempty_subsets       scgen_adapted              81       0.453110          0.329401          0.572781          1.0           1.0           2.0                  67                 81               0.827160              1.000000
# all_nonempty_subsets         sinkhorn_ot              81       0.420672          0.299347          0.548448          5.0           3.0           5.0                   0                  2               0.000000              0.024691
# all_nonempty_subsets          vae_latent              81       0.447229          0.322042          0.570478          3.0           1.0           4.0                   8                 58               0.098765              0.716049

# %% [markdown]
# ## Interpretation boundary
#
# The secondary cohort contains two animals in each age-by-oxygen group. Its ordering change is hypothesis-generating. Five hundred bootstrap replicates quantify resampling variability but do not increase biological replication.
